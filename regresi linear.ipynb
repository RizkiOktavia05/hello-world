# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x = [[151],[174],[148],[185],[154],[128],[135]]
y = [[63],[69],[50],[91],[48],[45],[47]]

model = LinearRegression()
model.fit(x,y)
y_predict = model.predict(x)

plt.figure()
plt.plot(x, y, 'r.')
plt.axis([120, 200, 30, 100])
plt.xlabel('tinggi badan')
plt.ylabel('berat badan')
plt.grid(True)
plt.plot(x, y_predict, color='b')
print('Jika tinggi badan 130 maka berat badannya adalah %.2f' %model.predict([[130]]))
plt.show
# Out:
# Jika tinggi badan 130 maka berat badannya adalah 41.37
# <function matplotlib.pyplot.show(*args, **kw)>
